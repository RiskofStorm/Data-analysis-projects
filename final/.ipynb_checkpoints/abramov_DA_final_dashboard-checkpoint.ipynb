# %% [markdown]
# Приветвую, Петр! Возможны проблемы с allign'ом e дашборда, я сделал auto при выборе размера дашборда, но фильтры почему-то на   сайте отображаются не полностью, а вот через кнопку "full screen"(нижний правый угол (PS это я так на всякий случай)) все ок

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Здравствуй, всё по ТЗ и открылось, молодец, удачи с оставшейся парочкой проектов. Чудесно исчезает и появляется диапазон дат, при игре с этим фильтром

# %% [markdown]
# # 5. Дашборд

# %% [markdown]
# https://public.tableau.com/app/profile/daniel2362/viz/DA_Abramov_final_project/final_dash?publish=yes

# %% [markdown]
# ![image.png](attachment:image.png)
